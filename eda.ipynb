# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp

# %%
df=pd.read_csv(r'D:\AI\fast_food_dataset (1).csv')

# %%
df.head(10)
# Out:
#          state     region  fast_food_millions
# 0      Alabama      South                  83
# 1       Alaska       West                  80
# 2      Arizona       West                  81
# 3     Arkansas      South                  45
# 4   California       West                  52
# 5     Colorado       West                  84
# 6  Connecticut  Northeast                  13
# 7     Delaware      South                  39
# 8      Florida      South                  78
# 9      Georgia      South                  29

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# (100, 3)
# Index(['state', 'region', 'fast_food_millions'], dtype='object')
# state                 object
# region                object
# fast_food_millions     int64
# dtype: object

# %%
print(df.isnull)
print(df.duplicated)
# Out:
# <bound method DataFrame.isnull of                     state     region  fast_food_millions
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
# [100 rows x 3 columns]>
# <bound method DataFrame.duplicated of                     state     region  fast_food_millions
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
# [100 rows x 3 columns]>

# %%
df.describe()
# Out:
#        fast_food_millions
# count          100.000000
# mean            64.160000
# std             27.981856
# min             11.000000
# 25%             42.500000
# 50%             72.000000
# 75%             85.000000
# max            100.000000

# %%
plt.hist(df['fast_food_millions'])
# Out:
# (array([12.,  3.,  8.,  5., 10.,  3., 13., 15., 10., 21.]),
#  array([ 11. ,  19.9,  28.8,  37.7,  46.6,  55.5,  64.4,  73.3,  82.2,
#          91.1, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
print(df.sort_values(by='fast_food_millions', ascending=False)['state'].head(10))
print(df.sort_values(by='fast_food_millions', ascending=False)['state'].tail(10))
# Out:
# 26                Nebraska
# 55    Pennsylvania_extra37
# 41               Tennessee
# 37            Pennsylvania
# 53       Tennessee_extra41
# 91       Tennessee_extra41
# 75    Pennsylvania_extra37
# 57        Nebraska_extra26
# 64           Idaho_extra11
# 11                   Idaho
# Name: state, dtype: object
# 94    North Dakota_extra33
# 33            North Dakota
# 72    North Dakota_extra33
# 49                 Wyoming
# 34                    Ohio
# 51         Wyoming_extra49
# 68         Wyoming_extra49
# 6              Connecticut
# 17               Louisiana
# 88       Louisiana_extra17
# Name: state, dtype: object

# %%
avg_fastfood=df.groupby('region')['fast_food_millions'].mean()
plt.bar(avg_fastfood.index,avg_fastfood.values)
plt.xlabel('region')
plt.ylabel('average fast food')
# Out:
# Text(0, 0.5, 'average fast food')

# %%
sns.boxplot(x='region',y='fast_food_millions',data=df)
# Out:
# <Axes: xlabel='region', ylabel='fast_food_millions'>

# %%
print(np.var(df['fast_food_millions']))
print(np.std(df['fast_food_millions']))
print(np.mean(df['fast_food_millions']))
print(np.median(df['fast_food_millions']))
df['fast_food_millions'].mode()
# Out:
# 775.1544
# 27.841594781908597
# 64.16
# 72.0
# 0    100
# Name: fast_food_millions, dtype: int64

# %%
df.groupby('region')['fast_food_millions'].max()
# Out:
# region
# Midwest      100
# Northeast    100
# South        100
# West          99
# Name: fast_food_millions, dtype: int64

# %%
df
# Out:
#                     state     region  fast_food_millions
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
# [100 rows x 3 columns]

# %%
nation_avg=df['fast_food_millions'].mean()
aboveavg_count=(df['fast_food_millions']>nation_avg).sum()
total_count=df['fast_food_millions'].count()
aboveavg_count
# total_count
# Out:
# np.int64(59)

# %%
probability=aboveavg_count/total_count
print(probability)
# Out:
# 0.59

# %%
numpy_array1= np.array(df['fast_food_millions'])
df['health_awarness_factor']=np.random.rand(len(df))
numpy_array2=np.array(df['health_awarness_factor'])
np.add(numpy_array1,numpy_array2)
# Out:
# array([ 83.75428458,  80.93497936,  81.10300482,  45.17522318,
#         52.97815219,  84.47733829,  13.6667339 ,  39.79485807,
#         78.28028055,  29.32586296,  81.14050414,  99.93475964,
#         67.30025072,  82.24354186,  27.25915835,  50.84829964,
#         99.76885443,  11.33038567,  85.51287385,  47.09696681,
#         71.3906695 ,  60.81403677,  28.97932275,  87.34093581,
#         69.66598348,  73.91461103, 100.48696982,  36.41039432,
#         92.13022306,  33.18710261,  92.52888256,  17.77708058,
#         98.86950472,  16.46807367,  15.32606204,  43.54462858,
#         93.5421404 , 100.23665329,  47.34213848,  62.2774582 ,
#         33.39838639, 100.51093494,  94.01551685,  41.10124937,
#         48.6028835 ,  79.81666323,  80.90481964,  49.37139873,
#         35.27182382,  15.39298615,  84.82964423,  15.45684093,
#         69.11068342, 100.06786562,  80.14350564, 100.18275364,
#         48.49541267, 100.19898481,  80.76130822,  49.93372291,
#         85.26336612,  36.51715193,  85.47380773,  83.00136076,
#         99.58973171,  33.54270358,  69.08041234,  71.79373111,
#         15.0462113 ,  98.35911241,  79.71597766,  17.66939896,
#         16.70888838,  94.23075572,  67.70942063, 100.59046428,
#         79.37226649,  27.00021571,  87.15209298,  73.61283295,
#         79.79453787,  43.51341543,  82.47806581,  33.54808662,
#         67.73726223,  67.62497169,  98.16242724,  73.93347723,
#         11.68036483,  52.52173354,  92.3517097 , 100.5391051 ,
#         50.50765833,  62.49084255,  16.29192723,  92.15289756,
#         87.50421869,  73.20658814,  81.35942706,  82.83452783])

# %%
np.subtract(numpy_array1,numpy_array2)
# Out:
# array([82.24571542, 79.06502064, 80.89699518, 44.82477682, 51.02184781,
#        83.52266171, 12.3332661 , 38.20514193, 77.71971945, 28.67413704,
#        80.85949586, 98.06524036, 66.69974928, 81.75645814, 26.74084165,
#        49.15170036, 98.23114557, 10.66961433, 84.48712615, 46.90303319,
#        70.6093305 , 59.18596323, 27.02067725, 86.65906419, 68.33401652,
#        72.08538897, 99.51303018, 35.58960568, 91.86977694, 32.81289739,
#        91.47111744, 16.22291942, 97.13049528, 15.53192633, 14.67393796,
#        42.45537142, 92.4578596 , 99.76334671, 46.65786152, 61.7225418 ,
#        32.60161361, 99.48906506, 93.98448315, 40.89875063, 47.3971165 ,
#        78.18333677, 79.09518036, 48.62860127, 34.72817618, 14.60701385,
#        83.17035577, 14.54315907, 68.88931658, 99.93213438, 79.85649436,
#        99.81724636, 47.50458733, 99.80101519, 79.23869178, 48.06627709,
#        84.73663388, 35.48284807, 84.52619227, 82.99863924, 98.41026829,
#        32.45729642, 68.91958766, 70.20626889, 14.9537887 , 97.64088759,
#        78.28402234, 16.33060104, 15.29111162, 93.76924428, 66.29057937,
#        99.40953572, 78.62773351, 26.99978429, 86.84790702, 72.38716705,
#        78.20546213, 42.48658457, 81.52193419, 32.45191338, 66.26273777,
#        66.37502831, 97.83757276, 72.06652277, 10.31963517, 51.47826646,
#        91.6482903 , 99.4608949 , 49.49234167, 61.50915745, 15.70807277,
#        91.84710244, 86.49578131, 72.79341186, 80.64057294, 81.16547217])

# %%
np.dot(numpy_array1,numpy_array2)
# Out:
# np.float64(3015.305550629971)

# %%
features=df[['fast_food_millions','health_awarness_factor']].values
weight_vector=np.array([0.7,0.3])
total=features@weight_vector
print(total)
# Out:
# [58.32628538 56.28049381 56.73090145 31.55256695 36.69344566 58.94320149
#   9.30002017 27.53845742 54.68408416 20.39775889 56.74215124 69.58042789
#  46.99007522 57.47306256 18.9777475  35.25448989 69.53065633  7.7991157
#  59.65386216 32.92909004 49.81720085 42.24421103 19.89379683 61.00228074
#  48.49979504 51.37438331 70.14609094 25.3231183  64.43906692 23.15613078
#  64.55866477 12.13312417 68.86085142 11.3404221  10.59781861 30.26338857
#  65.26264212 70.07099599 33.00264155 43.48323746 23.21951592 70.15328048
#  65.80465506 28.73037481 33.78086505 55.54499897 56.27144589 34.41141962
#  24.58154715 10.61789585 59.04889327 10.63705228 48.33320503 70.02035969
#  56.04305169 70.05482609 33.7486238  70.05969544 56.22839247 34.58011687
#  59.57900984 25.35514558 59.64214232 58.10040823 69.47691951 23.26281107
#  48.3241237  49.93811933 10.51386339 68.70773372 55.5147933  12.10081969
#  11.41266651 65.86922672 47.11282619 70.17713928 55.41167995 18.90006471
#  60.94562789 51.28384988 55.53836136 30.25402463 57.54341974 23.26442599
#  47.12117867 47.08749151 68.64872817 51.38004317  7.90410945 36.55652006
#  64.50551291 70.16173153 35.1522975  43.54725277 11.28757817 64.44586927
#  61.05126561 51.16197644 56.80782812 57.65035835]

# %%
df
# Out:
#                     state     region  fast_food_millions  \
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
#     health_awarness_factor
# 0                 0.754285
# 1                 0.934979
# 2                 0.103005
# 3                 0.175223
# 4                 0.978152
# ..                     ...
# 95                0.152898
# 96                0.504219
# 97                0.206588
# 98                0.359427
# 99                0.834528
#
# [100 rows x 4 columns]

# %%
fast_food_millions=sp.symbols('fast_food_millions')
population_in_millions=sp.symbols('population_in_millions')
unhealthy_index=(fast_food_millions / population_in_millions)*100
sp.diff(unhealthy_index,fast_food_millions)
# Out:
# 100/population_in_millions

# %%
df['above_average']=(df['fast_food_millions']>nation_avg).astype(int)
df['above_average']
# Out:
# 0     1
# 1     1
# 2     1
# 3     0
# 4     0
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: above_average, Length: 100, dtype: int64

# %%
df['spending_per_capita']=np.random.randint(1,50,size=len(df))
df
# Out:
#                     state     region  fast_food_millions  \
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
#     health_awarness_factor  above_average  spending_per_capita
# 0                 0.754285              1                    4
# 1                 0.934979              1                   48
# 2                 0.103005              1                    8
# 3                 0.175223              0                   38
# 4                 0.978152              0                    6
# ..                     ...            ...                  ...
# 95                0.152898              1                    8
# 96                0.504219              1                    7
# 97                0.206588              1                   47
# 98                0.359427              1                   21
# 99                0.834528              1                   21
#
# [100 rows x 6 columns]

# %%
total_spending=df.groupby('region')['fast_food_millions'].sum()
total_spending.sort_values(ascending=False)
# Out:
# region
# South        2192
# West         1668
# Midwest      1327
# Northeast    1229
# Name: fast_food_millions, dtype: int64

# %%
df['Spending_Quartile'] = pd.qcut(df['fast_food_millions'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

# %%
df['Spending_Quartile']
# Out:
# 0     Q3
# 1     Q3
# 2     Q3
# 3     Q2
# 4     Q2
#       ..
# 95    Q4
# 96    Q4
# 97    Q3
# 98    Q3
# 99    Q3
# Name: Spending_Quartile, Length: 100, dtype: category
# Categories (4, object): ['Q1' < 'Q2' < 'Q3' < 'Q4']

# %%
threshold_value = df['fast_food_millions'].quantile(0.75)
top_25_percent = df[df['fast_food_millions'] >= threshold_value]
top_25_percent.sort_values(by=['fast_food_millions','state'],ascending=False)
# Out:
#                      state     region  fast_food_millions  \
# 53       Tennessee_extra41      South                 100
# 91       Tennessee_extra41      South                 100
# 41               Tennessee      South                 100
# 55    Pennsylvania_extra37  Northeast                 100
# 75    Pennsylvania_extra37  Northeast                 100
# 37            Pennsylvania  Northeast                 100
# 57        Nebraska_extra26    Midwest                 100
# 26                Nebraska    Midwest                 100
# 16                Kentucky      South                  99
# 64           Idaho_extra11       West                  99
# 11                   Idaho       West                  99
# 69  North Carolina_extra32      South                  98
# 86  North Carolina_extra32      South                  98
# 32          North Carolina      South                  98
# 73           Texas_extra42      South                  94
# 42                   Texas      South                  94
# 36                  Oregon       West                  93
# 30              New Mexico       West                  92
# 90   New Hampshire_extra28  Northeast                  92
# 95   New Hampshire_extra28  Northeast                  92
# 28           New Hampshire  Northeast                  92
# 78     Mississippi_extra23      South                  87
# 96     Mississippi_extra23      South                  87
# 23             Mississippi      South                  87
# 60           Maine_extra18  Northeast                  85
# 62           Maine_extra18  Northeast                  85
# 18                   Maine  Northeast                  85
#
#     health_awarness_factor  above_average  spending_per_capita  \
# 53                0.067866              1                   16
# 91                0.539105              1                   31
# 41                0.510935              1                   35
# 55                0.182754              1                   39
# 75                0.590464              1                   44
# 37                0.236653              1                   11
# 57                0.198985              1                   24
# 26                0.486970              1                   32
# 16                0.768854              1                   23
# 64                0.589732              1                    6
# 11                0.934760              1                   33
# 69                0.359112              1                   33
# 86                0.162427              1                    2
# 32                0.869505              1                   29
# 73                0.230756              1                   46
# 42                0.015517              1                   12
# 36                0.542140              1                   17
# 30                0.528883              1                   10
# 90                0.351710              1                   12
# 95                0.152898              1                    8
# 28                0.130223              1                   20
# 78                0.152093              1                   29
# 96                0.504219              1                    7
# 23                0.340936              1                    8
# 60                0.263366              1                   22
# 62                0.473808              1                   45
# 18                0.512874              1                   17
#
#    Spending_Quartile
# 53                Q4
# 91                Q4
# 41                Q4
# 55                Q4
# 75                Q4
# 37                Q4
# 57                Q4
# 26                Q4
# 16                Q4
# 64                Q4
# 11                Q4
# 69                Q4
# 86                Q4
# 32                Q4
# 73                Q4
# 42                Q4
# 36                Q4
# 30                Q4
# 90                Q4
# 95                Q4
# 28                Q4
# 78                Q4
# 96                Q4
# 23                Q4
# 60                Q3
# 62                Q3
# 18                Q3

# %%
df.groupby('region')['fast_food_millions'].sum()
# Out:
# region
# Midwest      1327
# Northeast    1229
# South        2192
# West         1668
# Name: fast_food_millions, dtype: int64

# %%
df.groupby('region')['fast_food_millions'].sum().idxmax()
# Out:
# 'South'

# %%
df.groupby('state')['fast_food_millions'].sum().idxmax()
# Out:
# 'Virginia_extra45'

# %%
c1=(df['fast_food_millions']>nation_avg).sum()
c2=len(df)

# %%
percentage=c1/c2*100
print(f"percentagof states spend more that national average:{percentage}")
# Out:
# percentagof states spend more that national average:59.0

# %%
df
# Out:
#                     state     region  fast_food_millions  \
# 0                 Alabama      South                  83
# 1                  Alaska       West                  80
# 2                 Arizona       West                  81
# 3                Arkansas      South                  45
# 4              California       West                  52
# ..                    ...        ...                 ...
# 95  New Hampshire_extra28  Northeast                  92
# 96    Mississippi_extra23      South                  87
# 97        Montana_extra25       West                  73
# 98         Hawaii_extra10       West                  81
# 99        Indiana_extra13    Midwest                  82
#
#     health_awarness_factor  above_average  spending_per_capita  \
# 0                 0.754285              1                    4
# 1                 0.934979              1                   48
# 2                 0.103005              1                    8
# 3                 0.175223              0                   38
# 4                 0.978152              0                    6
# ..                     ...            ...                  ...
# 95                0.152898              1                    8
# 96                0.504219              1                    7
# 97                0.206588              1                   47
# 98                0.359427              1                   21
# 99                0.834528              1                   21
#
#    Spending_Quartile
# 0                 Q3
# 1                 Q3
# 2                 Q3
# 3                 Q2
# 4                 Q2
# ..               ...
# 95                Q4
# 96                Q4
# 97                Q3
# 98                Q3
# 99                Q3
#
# [100 rows x 7 columns]
